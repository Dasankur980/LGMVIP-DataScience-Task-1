# %% [markdown]
# ### __LETS GROW MORE__
# ### __TASK:- 1__
# ### __IRIS FLOWER CLASSIFICATION ML PROJECT__
# ### __NAME:-ANKUR DAS__

# %%
#importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
# %matplotlib inline

# %%
#Loading the columns into the Data by declaring the names of the columns
iris=pd.read_csv('iris.data',names=['Sepal Length','Sepal Width','Petal Length','Petal Width','Class'])
iris.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.dtypes
# Out:
# Sepal Length    float64
# Sepal Width     float64
# Petal Length    float64
# Petal Width     float64
# Class            object
# dtype: object

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal Length  150 non-null    float64
#  1   Sepal Width   150 non-null    float64
#  2   Petal Length  150 non-null    float64
#  3   Petal Width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Displaying Data of Iris in Array Form
irisdata=np.loadtxt("iris.data",delimiter=",",dtype=str)
display(irisdata)
# Out:
# array([['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'],
#        ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa'],
#        ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa'],
#        ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa'],
#        ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa'],
#        ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa'],
#        ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa'],
#        ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa'],
#        ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa'],
#        ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa'],
#        ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa'],
#        ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa'],
#        ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa'],
#        ['4.3', '3.0', '1.1', '0.1', 'Iris-setosa'],
#        ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa'],
#        ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa'],
#        ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa'],
#        ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa'],
# ...

# %%
iris.sum()
# Out:
# Sepal Length                                                876.5
# Sepal Width                                                 458.1
# Petal Length                                                563.8
# Petal Width                                                 179.8
# Class           Iris-setosaIris-setosaIris-setosaIris-setosaIr...
# dtype: object

# %%
iris.isnull().sum()
# Out:
# Sepal Length    0
# Sepal Width     0
# Petal Length    0
# Petal Width     0
# Class           0
# dtype: int64

# %%
#Description about classification of Iris
iris.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### __Heatmap__

# %%
plt.figure(figsize=(16,5))
sns.heatmap(iris.corr(),annot=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10688\779936276.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ### __PairPlot__

# %%
sns.pairplot(iris,hue='Class',diag_kind='hist',palette='husl')

# %%
#Dividing the Iris Information into x and y
x=iris.values[:,0:4]
y=iris.values[:,4]

# %%
#Splicing the Iris Data into Train and Test set
from sklearn.model_selection import train_test_split
iris_x_train,iris_x_test,iris_y_train,iris_y_test=train_test_split(x,y,test_size=0.47,random_state=20)
print(iris_x_train)
# Out:
# [[5.4 3.  4.5 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.1 3.  4.6 1.4]
#  [5.1 3.8 1.5 0.3]
#  [5.3 3.7 1.5 0.2]
#  [6.4 3.2 5.3 2.3]
#  [5.5 3.5 1.3 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.  2.  3.5 1. ]
#  [6.  3.  4.8 1.8]
#  [5.8 2.7 5.1 1.9]
#  [5.6 2.8 4.9 2. ]
#  [6.3 2.9 5.6 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.1 3.  5.9 2.1]
#  [5.8 2.7 3.9 1.2]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.  6.1 2.3]
#  [7.2 3.6 6.1 2.5]
#  [4.4 2.9 1.4 0.2]
#  [6.8 3.  5.5 2.1]
#  [5.2 3.5 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.8 4.  1.2 0.2]
#  [6.7 3.  5.2 2.3]
#  [6.9 3.1 4.9 1.5]
#  [5.9 3.2 4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.3 2.7 4.9 1.8]
#  [5.6 2.7 4.2 1.3]
#  [4.4 3.2 1.3 0.2]
#  [6.1 3.  4.9 1.8]
#  [5.5 4.2 1.4 0.2]
#  [5.  2.3 3.3 1. ]
#  [7.7 3.8 6.7 2.2]
#  [4.8 3.4 1.9 0.2]
#  [6.  2.9 4.5 1.5]
#  [6.1 2.9 4.7 1.4]
#  [6.2 2.8 4.8 1.8]
#  [4.8 3.  1.4 0.3]
#  [4.7 3.2 1.6 0.2]
#  [7.2 3.2 6.  1.8]
#  [6.7 3.3 5.7 2.5]
#  [5.2 2.7 3.9 1.4]
#  [5.5 2.6 4.4 1.2]
#  [5.7 2.6 3.5 1. ]
#  [6.7 3.3 5.7 2.1]
# ...

# %% [markdown]
# ### __Logistic Regression Model__

# %%
#Importing Logistic Regression from sklearn.linearmodel and declaring it

from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(iris_x_train,iris_y_train)
# Out:
# LogisticRegression()

# %%
#Declaration of Predicting Variable

pred=lr.predict(iris_x_test)

# %%
#F1 Score

f1=f1_score(iris_y_test,pred,average='micro')
print("F1 Score:- ",f1)
# Out:
# F1 Score:-  0.971830985915493

# %%
#Accuracy Score

acuscore=accuracy_score(iris_y_test,pred)
print("Accuracy Score:- ",acuscore*100,"%")
# Out:
# Accuracy Score:-  97.1830985915493 %

# %% [markdown]
# ### __Random Forest Classifier Model__

# %%
#Importing Random Forest Classifier from sklearn.ensmeble and declaring it

from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(iris_x_train,iris_y_train)
# Out:
# RandomForestClassifier()

# %%
#Declaration of Predicting Variable

pred=rfc.predict(iris_x_test)

# %%
#F1 Score

f1=f1_score(iris_y_test,pred,average='micro')
print("F1 Score:- ",f1)
# Out:
# F1 Score:-  0.9295774647887324

# %%
#Accuracy Score

acuscore=accuracy_score(iris_y_test,pred)
print("Accuracy Score:- ",acuscore*100,"%")
# Out:
# Accuracy Score:-  92.95774647887323 %

# %% [markdown]
# ### __Support Vector Classification Model__

# %%
#Importing SVC(Support Vector Classification) from sklearn.svm and declaring it

from sklearn.svm import SVC
svc=SVC()
svc.fit(iris_x_train,iris_y_train)
# Out:
# SVC()

# %%
#Declaration of Predicting Variable

pred=svc.predict(iris_x_test)

# %%
#F1 Score

f1=f1_score(iris_y_test,pred,average='micro')
print("F1 Score:- ",f1)
# Out:
# F1 Score:-  0.9577464788732394

# %%
#Accuracy Score

acuscore=accuracy_score(iris_y_test,pred)
print("Accuracy Score:- ",acuscore*100,"%")
# Out:
# Accuracy Score:-  95.77464788732394 %

# %% [markdown]
# ## __Confusion Matrix__

# %%
print("Confusion Matrix:- \n",confusion_matrix(iris_y_test,pred))
# Out:
# Confusion Matrix:-
#  [[23  0  0]
#  [ 0 30  0]
#  [ 0  2 16]]

# %% [markdown]
# ## __Classification Report__

# %% [markdown]
# #### __Iris-Setosa:- 0.0__
# #### __Iris-Versicolor:- 1.0__
# #### __Iris-Virginica:- 2.0__

# %%
print("Classification Report of Iris:- \n",classification_report(iris_y_test,pred))
# Out:
# Classification Report of Iris:-
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        23
#          1.0       0.94      1.00      0.97        30
#          2.0       1.00      0.89      0.94        18
#
#     accuracy                           0.97        71
#    macro avg       0.98      0.96      0.97        71
# weighted avg       0.97      0.97      0.97        71

# %%
irisprednew=np.array([[5.1,3.5,1.4,0.2],[6.4,3.2,4.5,1.5],[6.2,3.4,5.4,2.3]])
predic=lr.predict(irisprednew)
print("Prediction of the Iris Flower Species from the given array:-",format(predic))
# Out:
# Prediction of the Iris Flower Species from the given array:- [0. 1. 2.]

# %% [markdown]
# ## __Conclusion__
# #### __Hence the Logistic Regression Model is able to classify the Iris Flower at an accuracy of 97.1830 %__
